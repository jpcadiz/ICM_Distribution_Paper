# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (update to your data if necessary)
data = [
    [0.80, -0.43, 0.13, -0.01, 0.02, 0.02, -0.04, 0.11, 0.02, 0.05, 0.24, ],
    [0.80, -0.42, 0.10, 0.03, 0.03, 0.03, -0.06, 0.10, -0.02, 0.04, 0.22, -0.02],
    [0.80, -0.39, 0.13, 0.01, 0.03, 0.04, -0.07, 0.10, 0.02, 0.00, 0.21, 0.02],
    [0.80, -0.43, 0.11, 0.02, 0.04, -0.02, -0.09, 0.14, 0.02, 0.03, 0.21, 0.01],
    [0.92, -0.17, 0.03, 0.07, 0.01, 0.01, 0.02, 0.04, 0.33, 0.02, 0.06, 0.01],
    [0.92, -0.16, 0.01, 0.05, 0.02, 0.02, -0.01, 0.02, 0.30, -0.01, 0.05, -0.04],
    [0.95, -0.13, -0.01, 0.02, 0.03, 0.04, 0.00, 0.00, 0.23, -0.02, 0.06, -0.01],
    [0.95, -0.17, -0.01, 0.06, 0.01, 0.02, -0.04, 0.04, 0.23, 0.02, 0.06, 0.01],
    [0.45, -0.73, 0.01, 0.01, 0.00, 0.01, 0.01, -0.01, 0.01, 0.28, 0.07, 0.02],
    [0.47, -0.71, 0.01, 0.02, -0.02, -0.03, -0.01, 0.00, 0.01, 0.26, 0.06, 0.06],
    [0.44, -0.73, 0.01, 0.03, 0.02, 0.00, -0.05, 0.02, 0.00, 0.25, 0.03, 0.01],
    [0.47, -0.74, 0.01, 0.05, -0.03, 0.00, 0.02, 0.01, 0.02, 0.28, 0.01, 0.03]
]

variables = [
    "Electricity Cost", "Utilization", "Fuel Price", "Truck Distribution Leakage",
    "Gas Station Leak", "Gas Transmission Leak", "Fuel Economy", "Cab Cost", 
    "Liquid CapEx", "Compressor CapEx", "Station CapEx", "Pipeline CapEx"
]


df = pd.DataFrame(data, columns=cities_modes, index=variables).T

# Ensure absolute values for correct intensity
df_abs = df.abs()

# Create the plot
plt.figure(figsize=(14, 8))
ax = sns.heatmap(df_abs, cmap='Blues', annot=False, cbar_kws={"label": "Absolute Value of the Correlation Coefficients"})

# Annotate every cell manually with the correct value
for i in range(df.shape[0]):
    for j in range(df.shape[1]):
        text = f"{df.values[i, j]:.2f}"  # Format to 2 decimal places
        ax.text(j + 0.5, i + 0.5, text, ha='center', va='center', fontsize=8, color='black')

# Set custom tick labels for cities without modes
city_labels = ["New Haven", "Fresno", "Atlanta", "Miami"] * 3

# Set dashed lines for mode grouping
for pos in [4, 8]:  # Positions to place the dividing lines between modes
    plt.axvline(x=pos, color='gray', linestyle='--', lw=2)

# Set the x-axis labels with only cities
ax.set_xticklabels(city_labels, rotation=0, ha="center", fontsize=8, fontweight = 'bold')
# Make color bar label bold
cbar = ax.collections[0].colorbar
cbar.set_label("Absolute Correlation (+/-)", fontsize=12, weight='bold', rotation = -90, "pad": 15 )

# Set the mode labels manually at the top
plt.text(2, 13, "Gas", ha='center', va='center', fontsize=12, weight='bold')
plt.text(6, 13, "Liquid", ha='center', va='center', fontsize=12, weight='bold')
plt.text(10, 13, "Pipeline", ha='center', va='center', fontsize=12, weight='bold')

# Adjust y-axis labels
ax.set_yticklabels(variables, rotation=0, fontsize=8, fontweight = 'bold')

# Title and final adjustments
plt.title("Average of the Correlation Coefficients Across the Three Demand Levels in a Heatmap Grouped by Mode", fontsize=14)
plt.show()
# Out:
#   Cell In[67], line 55
#     cbar.set_label("Absolute Correlation (+/-)", fontsize=12, weight='bold', rotation = -90, pad )
#                                                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
city_mode_labels
# Out:
# ['New Haven', 'Fresno', 'Atlanta']
