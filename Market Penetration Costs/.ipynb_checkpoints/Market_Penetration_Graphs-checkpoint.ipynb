# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy.interpolate import interp1d
#
# # Load the dataset
# file_path = 'Distribution Paper - Market Penetration w_ CC.csv'
# data = pd.read_csv(file_path)
#
# # Clean and convert the Market Penetration Rate to numeric
# data['Market Penetration Rate'] = data['Market Penetration Rate'].str.rstrip('%').astype(float)
#
# # Define relevant columns
# x_col = 'Market Penetration Rate'
# y_col = 'Total Cost w/ Carbon Tax'
# city_col = 'City Name'
# delivery_col = 'Delivery Type'
# station_col = 'Station Size'
#
# # Define city colors and line styles for delivery modes
# city_colors = sns.color_palette("tab10", n_colors=data[city_col].nunique())
# delivery_styles = {"Gas": "solid", "Liquid": "dashed", "Pipe": "dotted"}
#
# # Get unique station sizes
# station_sizes = data[station_col].unique()
#
# # Create subplots for each station size
# fig, axes = plt.subplots(nrows=len(station_sizes), figsize=(12, 6 * len(station_sizes)))
#
# # Assign a color to each city
# city_color_map = {city: color for city, color in zip(data[city_col].unique(), city_colors)}
#
# # Function to find intersections
# def find_intersections(x1, y1, x2, y2):
#     f1 = interp1d(x1, y1, kind='linear', bounds_error=False, fill_value='extrapolate')
#     f2 = interp1d(x2, y2, kind='linear', bounds_error=False, fill_value='extrapolate')
#     fine_x = np.linspace(min(min(x1), min(x2)), max(max(x1), max(x2)), 1000)
#     diff = f1(fine_x) - f2(fine_x)
#     indices = np.where(np.diff(np.sign(diff)))[0]
#     intersections = []
#     for idx in indices:
#         x0 = fine_x[idx]
#         y0 = f1(x0)
#         intersections.append((x0, y0))
#     return intersections
#
# # Function to adjust annotation positions dynamically to avoid overlap
# def adjust_annotation_position(x0, y0, existing_positions, x_offset=2, y_offset=0.5):
#     for _ in range(100):  # Allow up to 100 adjustments to avoid infinite loops
#         adjusted_position = (x0 + x_offset, y0 + y_offset)
#         overlap = any(
#             abs(adjusted_position[0] - pos[0]) < 1 and abs(adjusted_position[1] - pos[1]) < 0.5
#             for pos in existing_positions
#         )
#         if not overlap:
#             existing_positions.append(adjusted_position)
#             return adjusted_position
#         # Increment offsets dynamically
#         x_offset += 1
#         y_offset += 0.3
#     return x0 + x_offset, y0 + y_offset  # Fallback position
#
# # Loop through each station size and plot
# for i, station_size in enumerate(station_sizes):
#     ax = axes[i] if len(station_sizes) > 1 else axes
#     station_data = data[data[station_col] == station_size]
#
#     # Group data by city
#     city_grouped = station_data.groupby(city_col)
#
#     for city, city_group in city_grouped:
#         grouped = city_group.groupby(delivery_col)
#
#         # Store lines for intersection detection
#         line_data = {}
#
#         for delivery, group in grouped:
#             group_sorted = group.sort_values(by=x_col)
#             x_vals = list(group_sorted[x_col].unique())  # Remove duplicates
#             leakage_grouped = group_sorted.groupby(x_col)[y_col]
#             avg_costs = leakage_grouped.mean()
#
#             # Extrapolate 40% if 39% exists
#             if 39.0 in avg_costs.index:
#                 extrapolated_avg = avg_costs.loc[39.0] + (avg_costs.loc[39.0] - avg_costs.loc[38.0]) if 38.0 in avg_costs.index else avg_costs.loc[39.0]
#                 avg_costs.loc[40.0] = extrapolated_avg
#
#             # Ensure arrays are sorted and aligned
#             x_vals = sorted(set(x_vals + [40.0]))  # Ensure 40.0 is included
#             avg_costs = avg_costs.reindex(x_vals).interpolate(method='linear')
#
#             # Store the line data for intersection detection
#             line_data[delivery] = (x_vals, avg_costs)
#
#             # Plot the line for the average value
#             ax.plot(
#                 x_vals, avg_costs, label=f'{city} - {delivery}', color=city_color_map[city], linestyle=delivery_styles[delivery], linewidth=4, alpha = 0.8
#
#             )
#
#         # Check for intersections between delivery modes within the same city
#         delivery_modes = list(line_data.keys())
#         existing_annotations = []  # Reset for each city
#         for j in range(len(delivery_modes)):
#             for k in range(j + 1, len(delivery_modes)):
#                 mode1 = delivery_modes[j]
#                 mode2 = delivery_modes[k]
#                 x1, y1 = line_data[mode1]
#                 x2, y2 = line_data[mode2]
#                 intersections = find_intersections(x1, y1, x2, y2)
#
#                 # Iterate through intersections and annotate with dynamic offsets
#                 for idx, (x0, y0) in enumerate(intersections):
#                     if city in ['Fresno, CA']:
#                         # Set custom offsets for Atlanta and Fresno
#                         x_offset = -2  # Move the box slightly left
#                         y_offset = -2 - idx  # Move the box lower
#                     elif city in ['Atlanta, GA']:
#                         # Set custom offsets for Atlanta and Fresno
#                         x_offset = 2  # Move the box slightly left
#                         y_offset = -0.65 - idx  # Move the box lower
#                     else:
#                         # Adjust the annotation position dynamically for other cities
#                         #x_offset, y_offset = adjust_annotation_position(x0, y0, existing_annotations)
#                         x_offset = 2
#                         y_offset = 1 +idx
#
#                     # Highlight the intersection
#                     ax.scatter(x0, y0, color='black', s=50, zorder=5)
#
#                     # Annotate with the adjusted position
#                     ax.annotate(
#                         f'{city}\n{mode1} ∩ {mode2}\n({x0:.1f}, {y0:.2f})',
#                         xy=(x0, y0), xycoords='data',
#                         xytext=(x0 + x_offset, y0 + y_offset), textcoords='data',
#                         arrowprops=dict(arrowstyle="->", color='black', lw=2),
#                         fontsize=12, bbox=dict(facecolor='white', alpha=0.8, edgecolor='black')
#                     )
#
#     # Customize each subplot
#     ax.set_xlim(1, 40)  # Ensure the x-axis spans from 1% to 40%
#     ax.set_ylim(3, 12)
#     ax.set_title(f'Station Size: {station_size}', fontsize=20, fontweight = 'bold')
#     ax.set_xlabel('Market Penetration Rate (%)', fontsize=14, fontweight = 'bold')
#     ax.set_ylabel('Total Cost with Carbon Tax ($/kg of H2)', fontsize=14, fontweight = 'bold')
#
#     # Position the legend outside the plot
#     ax.legend(
#         loc='upper left',
#         fontsize='small',
#         title='Mode',
#         bbox_to_anchor=(1.05, 1),
#         borderaxespad=0.
#     )
#     ax.grid(True)
#
# # Adjust layout
# plt.tight_layout()
# plt.savefig("Final Plots/Market Penetration.png")
# plt.show()

# %%
data[y_col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data[y_col]
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import seaborn as sns
from scipy.interpolate import UnivariateSpline

# Load and combine datasets with distance indicator
file_path_100 = 'Distribution Paper - Market Penetration w_ CC 100 km.csv'
file_path_250 = 'Distribution Paper - Market Penetration w_ CC 250 km.csv'
data_100 = pd.read_csv(file_path_100)
data_250 = pd.read_csv(file_path_250)

# Add Distance Column
data_100['Distance'] = 100
data_250['Distance'] = 250

# Combine into a single DataFrame
data = pd.concat([data_100, data_250], ignore_index=True)

# Clean and convert the Market Penetration Rate to numeric
data['Market Penetration Rate'] = data['Market Penetration Rate'].astype(float)*100#.str.rstrip('%').astype(float)

# Define relevant columns
x_col = 'Market Penetration Rate'
y_col = 'Total Costs'
city_col = 'City Name'
delivery_col = 'Delivery Type'
distance_col = 'Transmission Length'
demand_col = 'Station Size'  # Adjust if necessary

# Use a fully colorblind-safe palette with high contrast
palette = sns.color_palette("dark", n_colors=3)
delivery_colors = {'Gas': palette[0], 'Liquid': palette[1], 'Pipe': palette[2]}


# Get unique city and demand size combinations
cities = data[city_col].unique()
demand_sizes = data[demand_col].unique()

# Clean demand sizes to remove ' kg/day'
cleaned_demand_sizes = [size.split(' ')[0] for size in demand_sizes]  # Extract numeric part

# Loop through each cleaned demand size and create separate figures
for demand_size, clean_demand_size in zip(demand_sizes, cleaned_demand_sizes):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 12), constrained_layout=True)
    fig.suptitle(f'Station Capacity \n {demand_size}', fontsize=20, fontweight='bold')

    for ax, city in zip(axes.flat, cities):
        # Filter data for the specific city and demand size
        subset_data = data[(data[city_col] == city) & (data[demand_col] == demand_size)]

        # Plot for each delivery type and distance
        for delivery in subset_data[delivery_col].unique():
            for distance in [100, 250]:
                subset = subset_data[(subset_data[delivery_col] == delivery) & (subset_data[distance_col] == distance)]
                subset = subset.sort_values(by=x_col)

                # Group and smooth the data
                subset_grouped = subset.groupby(x_col, as_index=False)[y_col].mean()
                x_vals = subset_grouped[x_col].values
                avg_costs = subset_grouped[y_col].values

                # Interpolate and smooth line
                fine_x = np.linspace(min(x_vals), max(x_vals), 500)
                f_interpolate = interp1d(x_vals, avg_costs, kind='cubic', bounds_error=False, fill_value='extrapolate')
                smooth_y = f_interpolate(fine_x)
                # Apply spline with smoothing factor `s`
                #spline = UnivariateSpline(x_vals, avg_costs, s=5)  # Increase s for more smoothing
                #smooth_y = spline(fine_x)

                # Set linestyle and opacity based on distance
                linestyle = 'solid' if distance == 100 else 'dashed'
                alpha = 1.0 if distance == 100 else 0.6  # Set opacity
                linewidth = 2.5 if distance == 100 else 2  # Slightly thicker for 100 km


                # Plot with solid/dashed lines and different colors for modes
                ax.plot(
                    fine_x, smooth_y,
                    label=f'{delivery} ({distance} km)',
                    color=delivery_colors[delivery],
                    linestyle=linestyle,
                    linewidth=linewidth,
                    alpha=alpha
                )

        # Customize subplot
        city_name_only = city.split(",")[0]  # Extract only the city name before the comma
        ax.set_xlim(1, 40)
        ax.set_ylim(0, 14.001)
        ax.set_title(f'{city_name_only}', fontsize=16, fontweight='bold')
        ax.set_xlabel('Market Penetration Rate (%)', fontsize=10, fontweight='bold')
        ax.set_ylabel('Total Cost with Carbon Tax ($/kg)', fontsize=10, fontweight='bold')
        ax.grid(True)
        ax.legend(fontsize=12, loc='upper right')

    # Save and display the figure for the current demand level
    plt.savefig(f"../Final Plots/2x2_Grid_Demand_{clean_demand_size}.png")
    plt.show()

# %%
print(data.columns)
# Out:
# Index(['City Name', 'Delivery Type', 'Station Size', 'Leakage Level',
#        'Market Penetration Rate', 'Distribution Leakage',
#        'Transmission Leakage', 'Station Leakage Rates', 'Distribution GHG',
#        'Transmission GHG', 'Station GHG', 'H2 Deivery (Market Rate)',
#        'Total GHG', 'Total Costs', 'Total Cost w/ Carbon Tax'],
#       dtype='object')

# %%
cities = cities[:3]
demand_sizes = demand_sizes[:3]
demand_sizes
# Out:
# array(['1000 kg/day', '2000 kg/day', '3000 kg/day'], dtype=object)

# %%
demand_sizes
# Out:
# array(['1000 kg/day', '2000 kg/day', '3000 kg/day'], dtype=object)

# %%
data_100
# Out:
#          City Name Delivery Type Station Size Leakage Level  \
# 0    New Haven, CT           Gas  1000 kg/day        Medium
# 1    New Haven, CT           Gas  1000 kg/day        Medium
# 2    New Haven, CT           Gas  1000 kg/day        Medium
# 3    New Haven, CT           Gas  1000 kg/day        Medium
# 4    New Haven, CT           Gas  1000 kg/day        Medium
# ..             ...           ...          ...           ...
# 751      Miami, FL          Pipe  3000 kg/day        Medium
# 752      Miami, FL          Pipe  3000 kg/day        Medium
# 753      Miami, FL          Pipe  3000 kg/day        Medium
# 754      Miami, FL          Pipe  3000 kg/day        Medium
# 755      Miami, FL          Pipe  3000 kg/day        Medium
#
#     Market Penetration Rate  Distribution Leakage  Transmission Leakage  \
# 0                        1%                0.0018                0.0106
# 1                        3%                0.0018                0.0106
# ...
